# %% [markdown]
# # PC Class 1

# %% [markdown]
# ## task 1 – Setup the jupyter notebook guide

# %% [markdown]
# - open terminal
# - execute the following command
# ```bash
# $ git clone https://git.cs.kent.ac.uk/febo/notebook.git
# ```
# - [result: notebook](../../notebook/index.ipynb)

# %% [markdown]
# ## task : Fibonacci from java version to python version

# %% [markdown]
# ### java

# %% [markdown]
# ```java
# public class Fibonacci {
#     public static void main(String[] args) {
#         int n1 = 0;
#         int n2 = 1;
#
#         System.out.println(n1);
#
#         while (n2 < 22) {
#             System.out.println(n2);
#             int n3 = n1 + n2;
#             n1 = n2;
#             n2 = n3;
#         }
#     }
# }
# ```

# %% [markdown]
# ### python

# %%
n1 = 0
n2 = 1

# prints the first number
print(n1)

# prints the rest of the Fibonacci number less than 22
while n2 < 22:
    print(n2)
    n1, n2 = n2, n1 + n2
# Out:
# 0
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21
